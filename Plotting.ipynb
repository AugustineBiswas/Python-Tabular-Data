# %% [markdown]
# <a href="https://colab.research.google.com/github/AugustineBiswas/Python-Tabular-Data/blob/main/Plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !pip install matplotlib

# %%
from urllib.request import urlretrieve
italy_covid_url = 'https://gist.githubusercontent.com/aakashns/f6a004fa20c84fec53262f9a8bfee775/raw/f309558b1cf5103424cef58e2ecb8704dcd4d74c/italy-covid-daywise.csv'
urlretrieve(italy_covid_url, 'italy-covid-daywise.csv')
covid_df = pd.read_csv('italy-covid-daywise.csv')

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
covid_df.new_cases.plot()
# Out:
# <Axes: >

# %%
new_df=covid_df

# %%
new_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
new_df.new_cases.plot
# Out:
# <Axes: xlabel='date'>

# %%
covid_df
# Out:
#             new_cases  new_deaths  new_tests
# date
# 2019-12-31        0.0         0.0        NaN
# 2020-01-01        0.0         0.0        NaN
# 2020-01-02        0.0         0.0        NaN
# 2020-01-03        0.0         0.0        NaN
# 2020-01-04        0.0         0.0        NaN
# ...               ...         ...        ...
# 2020-08-30     1444.0         1.0    53541.0
# 2020-08-31     1365.0         4.0    42583.0
# 2020-09-01      996.0         6.0    54395.0
# 2020-09-02      975.0         8.0        NaN
# 2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 3 columns]

# %%
ncovid_df = pd.read_csv('italy-covid-daywise.csv')

# %%
ncovid_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
result_df=ncovid_df[['date','new_cases','new_deaths','new_tests']]

# %%
result_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
result_df.date
# Out:
# 0      2019-12-31
# 1      2020-01-01
# 2      2020-01-02
# 3      2020-01-03
# 4      2020-01-04
#           ...
# 243    2020-08-30
# 244    2020-08-31
# 245    2020-09-01
# 246    2020-09-02
# 247    2020-09-03
# Name: date, Length: 248, dtype: object

# %%
result_df['year'] = pd.DatetimeIndex(result_df.date).year
result_df['month'] = pd.DatetimeIndex(result_df.date).month
result_df['day'] = pd.DatetimeIndex(result_df.date).day
result_df['weekday'] = pd.DatetimeIndex(result_df.date).weekday

# %%
result_df
# Out:
#            date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 0    2019-12-31        0.0         0.0        NaN  2019     12   31        1
# 1    2020-01-01        0.0         0.0        NaN  2020      1    1        2
# 2    2020-01-02        0.0         0.0        NaN  2020      1    2        3
# 3    2020-01-03        0.0         0.0        NaN  2020      1    3        4
# 4    2020-01-04        0.0         0.0        NaN  2020      1    4        5
# ..          ...        ...         ...        ...   ...    ...  ...      ...
# 243  2020-08-30     1444.0         1.0    53541.0  2020      8   30        6
# 244  2020-08-31     1365.0         4.0    42583.0  2020      8   31        0
# 245  2020-09-01      996.0         6.0    54395.0  2020      9    1        1
# 246  2020-09-02      975.0         8.0        NaN  2020      9    2        2
# 247  2020-09-03     1326.0         6.0        NaN  2020      9    3        3
#
# [248 rows x 8 columns]

# %%
ncovid_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
result_df.set_index('date', inplace=True)

# %%
result_df.new_cases.plot()
# Out:
# <Axes: xlabel='date'>
