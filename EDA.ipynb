# %% [markdown]
# <a href="https://colab.research.google.com/github/AugustineBiswas/Python-Tabular-Data/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets

# %%
import opendatasets as od

# %%
od.download('stackoverflow-developer-survey-2020')
# Out:
# ...
# 94609408it [00:00, 114106656.69it/s]
# ...
# 16384it [00:00, 127010.15it/s]
# ...
# 8192it [00:00, 114233.93it/s]

# %%
import os

# %%
os.listdir('stackoverflow-developer-survey-2020')
# Out:
# ['survey_results_schema.csv', 'README.txt', 'survey_results_public.csv']

# %%
import pandas as pd

# %%
survey_raw_df = pd.read_csv('stackoverflow-developer-survey-2020/survey_results_public.csv')

# %%
survey_raw_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %% [markdown]
# we want only a few columns out of the 61 columns in the raw dataset. hence we create a list of the needed columns.

# %%
selected_columns = [
    # Demographics
    'Country',
    'Age',
    'Gender',
    'EdLevel',
    'UndergradMajor',
    # Programming experience
    'Hobbyist',
    'Age1stCode',
    'YearsCode',
    'YearsCodePro',
    'LanguageWorkedWith',
    'LanguageDesireNextYear',
    'NEWLearn',
    'NEWStuck',
    # Employment
    'Employment',
    'DevType',
    'WorkWeekHrs',
    'JobSat',
    'JobFactors',
    'NEWOvertime',
    'NEWEdImpt'
]

# %%
survey_df = survey_raw_df[selected_columns].copy()

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %% [markdown]
# in some of the columns we have object datatype instead of the numeric which we do not want. example:Age1stCode,YearsCode. we change it using "pd.to_numeric"

# %%
survey_df['Age1stCode'] = pd.to_numeric(survey_df.Age1stCode, errors='coerce')
survey_df['YearsCode'] = pd.to_numeric(survey_df.YearsCode, errors='coerce')
survey_df['YearsCodePro'] = pd.to_numeric(survey_df.YearsCodePro, errors='coerce')

# %%
survey_df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45446.000000  57473.000000  56784.000000  44133.000000  41151.000000
# mean      30.834111     15.476572     12.782051      8.869667     40.782174
# std        9.585392      5.114081      9.490657      7.759961     17.816383
# min        1.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     17.000000     12.000000     44.000000
# max      279.000000     85.000000     50.000000     50.000000    475.000000

# %% [markdown]
# There seems to be a problem with the age column, as the minimum value is 1 and the maximum is 279. This is a common issue with surveys: responses may contain invalid values due to accidental or intentional errors while responding. A simple fix would be to ignore the rows where the age is higher than 100 years or lower than 10 years as invalid survey responses. We can do this using the .drop method

# %%
survey_df.drop(survey_df[survey_df.Age < 10].index, inplace=True)
survey_df.drop(survey_df[survey_df.Age > 100].index, inplace=True)

# %% [markdown]
# The same holds for WorkWeekHrs. Let's ignore entries where the value for the column is higher than 140 hours. (~20 hours per day).

# %%
survey_df.drop(survey_df[survey_df.WorkWeekHrs > 140].index, inplace=True)

# %%
survey_df['Gender'].value_counts()
# Out:
# Gender
# Man                                                            45895
# Woman                                                           3835
# Non-binary, genderqueer, or gender non-conforming                385
# Man;Non-binary, genderqueer, or gender non-conforming            121
# Woman;Non-binary, genderqueer, or gender non-conforming           92
# Woman;Man                                                         73
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       25
# Name: count, dtype: int64

# %%
import numpy as np

# %%
survey_df.where(~(survey_df.Gender.str.contains(';', na=False)), np.nan, inplace=True)

# %%
survey_df.sample(10)
# Out:
#               Country   Age Gender  \
# 63753          Poland   NaN    NaN
# 50472           India  27.0    Man
# 59756  United Kingdom  26.0  Woman
# 11256         Austria  21.0    Man
# 31681         Germany  18.0    Man
# 8936            India  38.0    Man
# 46775   United States  32.0    Man
# 13488         Estonia  25.0    Man
# 54640        Pakistan   NaN    NaN
# 16187   United States  30.0    Man
#
#                                                  EdLevel  \
# 63753    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 50472       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 59756       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11256       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 31681  Secondary school (e.g. American high school, G...
# 8936     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 46775       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 13488       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
top_countries=survey_df.Country.value_counts().head(15)
top_countries
# Out:
# Country
# United States         12371
# India                  8364
# United Kingdom         3881
# Germany                3864
# Canada                 2175
# France                 1884
# Brazil                 1804
# Netherlands            1332
# Poland                 1259
# Australia              1199
# Spain                  1157
# Italy                  1115
# Russian Federation     1085
# Sweden                  879
# Pakistan                802
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
sns.barplot(x=top_countries.index, y=top_countries);

# %%
plt.figure(figsize=(12,6))
plt.xlabel('Age')
plt.ylabel('Number of respondents')
plt.hist(survey_df.Age,bins=np.arange(10,90,5));

# %%
gender_counts=survey_df.Gender.value_counts()
gender_counts
# Out:
# Gender
# Man                                                  45895
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=180);

# %%
plt.figure(figsize=(12,6))
sns.countplot(y=survey_df.EdLevel)
plt.xticks(rotation=75);
plt.ylabel(None);

# %%
(survey_df.Employment.value_counts(normalize=True, ascending=True)*100).plot(kind='barh', color='g')
plt.xlabel('Percentage');
