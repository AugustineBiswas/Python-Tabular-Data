# %%
import pandas as pd

# %%
italy_covid_url = 'https://gist.githubusercontent.com/aakashns/f6a004fa20c84fec53262f9a8bfee775/raw/f309558b1cf5103424cef58e2ecb8704dcd4d74c/italy-covid-daywise.csv'

urlretrieve(italy_covid_url, 'italy-covid-daywise.csv')
# Out:
# ('italy-covid-daywise.csv', <http.client.HTTPMessage at 0x7adffeba05b0>)

# %%
from urllib.request import urlretrieve

# %%
covid_df = pd.read_csv('italy-covid-daywise.csv')

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %% [markdown]
# Similar to Numpy arrays, a Pandas series supports the sum method to answer these questions.

# %%
total_cases=covid_df.new_cases.sum()
print('The number of reported cases is {} '.format(int(total_cases)))
# Out:
# The number of reported cases is 271515

# %%
high_new_cases=covid_df.new_cases >1000
high_new_cases
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 243     True
# 244     True
# 245    False
# 246    False
# 247     True
# Name: new_cases, Length: 248, dtype: bool

# %%
covid_df[high_new_cases]
# Out:
#            date  new_cases  new_deaths  new_tests
# 68   2020-03-08     1247.0        36.0        NaN
# 69   2020-03-09     1492.0       133.0        NaN
# 70   2020-03-10     1797.0        98.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 73   2020-03-13     2651.0       189.0        NaN
# ..          ...        ...         ...        ...
# 241  2020-08-28     1409.0         5.0    65135.0
# 242  2020-08-29     1460.0         9.0    64294.0
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 247  2020-09-03     1326.0         6.0        NaN
#
# [72 rows x 4 columns]

# %%
covid_df.sort_values('new_cases',ascending=False).head(10)
# Out:
#           date  new_cases  new_deaths  new_tests
# 82  2020-03-22     6557.0       795.0        NaN
# 87  2020-03-27     6153.0       660.0        NaN
# 81  2020-03-21     5986.0       625.0        NaN
# 89  2020-03-29     5974.0       887.0        NaN
# 88  2020-03-28     5959.0       971.0        NaN
# 83  2020-03-23     5560.0       649.0        NaN
# 80  2020-03-20     5322.0       429.0        NaN
# 85  2020-03-25     5249.0       743.0        NaN
# 90  2020-03-30     5217.0       758.0        NaN
# 86  2020-03-26     5210.0       685.0        NaN

# %% [markdown]
# Here's a summary of the functions & methods we looked at in this section:
#
# - `covid_df.new_cases.sum()` - Computing the sum of values in a column or series
# - `covid_df[covid_df.new_cases > 1000]` - Querying a subset of rows satisfying the chosen criteria using boolean expressions
# - `df['pos_rate'] = df.new_cases/df.new_tests` - Adding new columns by combining data from existing columns
# - `covid_df.drop('positive_rate')` - Removing one or more columns from the data frame
# - `sort_values` - Sorting the rows of a data frame using column values
# - `covid_df.at[172, 'new_cases'] = ...` - Replacing a value within the data frame

# %%
covid_df.date
# Out:
# 0      2019-12-31
# 1      2020-01-01
# 2      2020-01-02
# 3      2020-01-03
# 4      2020-01-04
#           ...
# 243    2020-08-30
# 244    2020-08-31
# 245    2020-09-01
# 246    2020-09-02
# 247    2020-09-03
# Name: date, Length: 248, dtype: object

# %%
covid_df['year'] = pd.DatetimeIndex(covid_df.date).year
covid_df['month'] = pd.DatetimeIndex(covid_df.date).month
covid_df['day'] = pd.DatetimeIndex(covid_df.date).day
covid_df['weekday'] = pd.DatetimeIndex(covid_df.date).weekday

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 0    2019-12-31        0.0         0.0        NaN  2019     12   31        1
# 1    2020-01-01        0.0         0.0        NaN  2020      1    1        2
# 2    2020-01-02        0.0         0.0        NaN  2020      1    2        3
# 3    2020-01-03        0.0         0.0        NaN  2020      1    3        4
# 4    2020-01-04        0.0         0.0        NaN  2020      1    4        5
# ..          ...        ...         ...        ...   ...    ...  ...      ...
# 243  2020-08-30     1444.0         1.0    53541.0  2020      8   30        6
# 244  2020-08-31     1365.0         4.0    42583.0  2020      8   31        0
# 245  2020-09-01      996.0         6.0    54395.0  2020      9    1        1
# 246  2020-09-02      975.0         8.0        NaN  2020      9    2        2
# 247  2020-09-03     1326.0         6.0        NaN  2020      9    3        3
#
# [248 rows x 8 columns]

# %% [markdown]
# ## Grouping and aggregation
#
# As a next step, we might want to summarize the day-wise data and create a new dataframe with month-wise data. We can use the `groupby` function to create a group for each month, select the columns we wish to aggregate, and aggregate them using the `sum` method.

# %%
covid_month_df
# Out:
#        new_cases  new_deaths  new_tests
# month
# 1            3.0         0.0        0.0
# 2          885.0        21.0        0.0
# 3       100851.0     11570.0        0.0
# 4       101852.0     16091.0   419591.0
# 5        29073.0      5658.0  1078720.0
# 6         7772.0      1404.0   830354.0
# 7         6722.0       388.0   797692.0
# 8        21060.0       345.0  1098704.0
# 9         3297.0        20.0    54395.0
# 12           0.0         0.0        0.0

# %%
urlretrieve('https://gist.githubusercontent.com/aakashns/8684589ef4f266116cdce023377fc9c8/raw/99ce3826b2a9d1e6d0bde7e9e559fc8b6e9ac88b/locations.csv',
            'locations.csv')
# Out:
# ('locations.csv', <http.client.HTTPMessage at 0x7adff83fada0>)

# %%
locations_df = pd.read_csv('locations.csv')
locations_df
# Out:
#           location continent    population  life_expectancy  \
# 0      Afghanistan      Asia  3.892834e+07            64.83
# 1          Albania    Europe  2.877800e+06            78.57
# 2          Algeria    Africa  4.385104e+07            76.88
# 3          Andorra    Europe  7.726500e+04            83.73
# 4           Angola    Africa  3.286627e+07            61.15
# ..             ...       ...           ...              ...
# 207          Yemen      Asia  2.982597e+07            66.12
# 208         Zambia    Africa  1.838396e+07            63.89
# 209       Zimbabwe    Africa  1.486293e+07            61.49
# 210          World       NaN  7.794799e+09            72.58
# 211  International       NaN           NaN              NaN
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                         0.500        1803.987
# 1                         2.890       11803.431
# 2                         1.900       13913.839
# 3                           NaN             NaN
# 4                           NaN        5819.495
# ..                          ...             ...
# 207                       0.700        1479.147
# 208                       2.000        3689.251
# 209                       1.700        1899.775
# 210                       2.705       15469.207
# 211                         NaN             NaN
#
# [212 rows x 6 columns]

# %%
locations_df[locations_df.continent == "Asia"]
# Out:
#                  location continent    population  life_expectancy  \
# 0             Afghanistan      Asia  3.892834e+07            64.83
# 8                 Armenia      Asia  2.963234e+06            75.09
# 12             Azerbaijan      Asia  1.013918e+07            73.00
# 14                Bahrain      Asia  1.701583e+06            77.29
# 15             Bangladesh      Asia  1.646894e+08            72.59
# 22                 Bhutan      Asia  7.716120e+05            71.78
# 29                 Brunei      Asia  4.374830e+05            75.86
# 33               Cambodia      Asia  1.671897e+07            69.82
# 41                  China      Asia  1.439324e+09            76.91
# 72                Georgia      Asia  3.989175e+06            73.77
# 87              Hong Kong      Asia  7.496988e+06            84.86
# 90                  India      Asia  1.380004e+09            69.66
# 91              Indonesia      Asia  2.735236e+08            71.72
# 92                   Iran      Asia  8.399295e+07            76.68
# 93                   Iraq      Asia  4.022250e+07            70.60
# 96                 Israel      Asia  8.655541e+06            82.97
# 99                  Japan      Asia  1.264765e+08            84.63
# 101                Jordan      Asia  1.020314e+07            74.53
# 102            Kazakhstan      Asia  1.877671e+07            73.60
# 105                Kuwait      Asia  4.270563e+06            75.49
# 106            Kyrgyzstan      Asia  6.524191e+06            71.45
# 107                  Laos      Asia  7.275556e+06            67.92
# 109               Lebanon      Asia  6.825442e+06            78.93
# 119              Malaysia      Asia  3.236600e+07            76.16
# 120              Maldives      Asia  5.405420e+05            78.92
# 128              Mongolia      Asia  3.278292e+06            69.87
# 133               Myanmar      Asia  5.440979e+07            67.13
# 135                 Nepal      Asia  2.913681e+07            70.78
# 144                  Oman      Asia  5.106622e+06            77.86
# 145              Pakistan      Asia  2.208923e+08            67.27
# 146             Palestine      Asia  5.101416e+06            74.05
# 151           Philippines      Asia  1.095811e+08            71.23
# 155                 Qatar      Asia  2.881060e+06            80.23
# 164          Saudi Arabia      Asia  3.481387e+07            75.13
# 169             Singapore      Asia  5.850343e+06            83.62
# 175           South Korea      Asia  5.126918e+07            83.03
# 178             Sri Lanka      Asia  2.141325e+07            76.98
# 184                 Syria      Asia  1.750066e+07            72.70
# 185                Taiwan      Asia  2.381678e+07            80.46
# 186            Tajikistan      Asia  9.537642e+06            71.10
# 188              Thailand      Asia  6.979998e+07            77.15
# 189                 Timor      Asia  1.318442e+06            69.50
# 193                Turkey      Asia  8.433907e+07            77.69
# 197  United Arab Emirates      Asia  9.890400e+06            77.97
# 202            Uzbekistan      Asia  3.346920e+07            71.72
# 205               Vietnam      Asia  9.733858e+07            75.40
# 207                 Yemen      Asia  2.982597e+07            66.12
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 8                          4.20        8787.580
# 12                         4.70       15847.419
# 14                         2.00       43290.705
# 15                         0.80        3523.984
# 22                         1.70        8708.597
# 29                         2.70       71809.251
# 33                         0.80        3645.070
# 41                         4.34       15308.712
# 72                         2.60        9745.079
# 87                          NaN       56054.920
# 90                         0.53        6426.674
# 91                         1.04       11188.744
# 92                         1.50       19082.620
# 93                         1.40       15663.986
# 96                         2.99       33132.320
# 99                        13.05       39002.223
# 101                        1.40        8337.490
# 102                        6.70       24055.588
# 105                        2.00       65530.537
# 106                        4.50        3393.474
# 107                        1.50        6397.360
# 109                        2.90       13367.565
# 119                        1.90       26808.164
# 120                         NaN       15183.616
# 128                        7.00       11840.846
# 133                        0.90        5591.597
# 135                        0.30        2442.804
# 144                        1.60       37960.709
# 145                        0.60        5034.708
# 146                         NaN        4449.898
# 151                        1.00        7599.188
# 155                        1.20      116935.600
# 164                        2.70       49045.411
# 169                        2.40       85535.383
# 175                       12.27       35938.374
# 178                        3.60       11669.077
# 184                        1.50             NaN
# 185                         NaN             NaN
# 186                        4.80        2896.913
# 188                        2.10       16277.671
# 189                        5.90        6570.102
# 193                        2.81       25129.341
# 197                        1.20       67293.483
# 202                        4.00        6253.104
# 205                        2.60        6171.884
# 207                        0.70        1479.147

# %%
locations_df[locations_df.location == "Italy"]
# Out:
#    location continent  population  life_expectancy  \
# 97    Italy    Europe  60461828.0            83.51
#
#     hospital_beds_per_thousand  gdp_per_capita
# 97                        3.18       35220.084

# %% [markdown]
# Here's a summary of the functions & methods we looked at in this section:
#
# - `covid_df.new_cases.sum()` - Computing the sum of values in a column or series
# - `covid_df[covid_df.new_cases > 1000]` - Querying a subset of rows satisfying the chosen criteria using boolean expressions
# - `df['pos_rate'] = df.new_cases/df.new_tests` - Adding new columns by combining data from existing columns
# - `covid_df.drop('positive_rate')` - Removing one or more columns from the data frame
# - `sort_values` - Sorting the rows of a data frame using column values
# - `covid_df.at[172, 'new_cases'] = ...` - Replacing a value within the data frame

# %%
import pandas as pd

# %%
covid_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6af809ebb883> in <cell line: 1>()
# ----> 1 covid_df
#
# NameError: name 'covid_df' is not defined

# %%
from urllib.request import urlretrieve
italy_covid_url = 'https://gist.githubusercontent.com/aakashns/f6a004fa20c84fec53262f9a8bfee775/raw/f309558b1cf5103424cef58e2ecb8704dcd4d74c/italy-covid-daywise.csv'
urlretrieve(italy_covid_url, 'italy-covid-daywise.csv')
# Out:
# ('italy-covid-daywise.csv', <http.client.HTTPMessage at 0x7ba5d60f7a60>)

# %%
covid_df = pd.read_csv('italy-covid-daywise.csv')

# %% [markdown]
# The data type of date is currently object, so Pandas does not know that this column is a date. We can convert it into a datetime column using the pd.to_datetime method.

# %%
covid_df['date']=pd.to_datetime(covid_df.date)

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests
# 0   2019-12-31        0.0         0.0        NaN
# 1   2020-01-01        0.0         0.0        NaN
# 2   2020-01-02        0.0         0.0        NaN
# 3   2020-01-03        0.0         0.0        NaN
# 4   2020-01-04        0.0         0.0        NaN
# ..         ...        ...         ...        ...
# 243 2020-08-30     1444.0         1.0    53541.0
# 244 2020-08-31     1365.0         4.0    42583.0
# 245 2020-09-01      996.0         6.0    54395.0
# 246 2020-09-02      975.0         8.0        NaN
# 247 2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
covid_df['date']
# Out:
# 0     2019-12-31
# 1     2020-01-01
# 2     2020-01-02
# 3     2020-01-03
# 4     2020-01-04
#          ...
# 243   2020-08-30
# 244   2020-08-31
# 245   2020-09-01
# 246   2020-09-02
# 247   2020-09-03
# Name: date, Length: 248, dtype: datetime64[ns]

# %%
covid_df['year'] = pd.DatetimeIndex(covid_df.date).year
covid_df['month'] = pd.DatetimeIndex(covid_df.date).month
covid_df['day'] = pd.DatetimeIndex(covid_df.date).day
covid_df['weekday'] = pd.DatetimeIndex(covid_df.date).weekday

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 0   2019-12-31        0.0         0.0        NaN  2019     12   31        1
# 1   2020-01-01        0.0         0.0        NaN  2020      1    1        2
# 2   2020-01-02        0.0         0.0        NaN  2020      1    2        3
# 3   2020-01-03        0.0         0.0        NaN  2020      1    3        4
# 4   2020-01-04        0.0         0.0        NaN  2020      1    4        5
# ..         ...        ...         ...        ...   ...    ...  ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020      8   30        6
# 244 2020-08-31     1365.0         4.0    42583.0  2020      8   31        0
# 245 2020-09-01      996.0         6.0    54395.0  2020      9    1        1
# 246 2020-09-02      975.0         8.0        NaN  2020      9    2        2
# 247 2020-09-03     1326.0         6.0        NaN  2020      9    3        3
#
# [248 rows x 8 columns]

# %% [markdown]
# Now if we want the metrics only for the month of May, we could do the following.

# %%
covid_df_may=covid_df[covid_df.month==5]

# %%
covid_df_may
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 122 2020-05-01     1872.0       285.0    43732.0  2020      5    1        4
# 123 2020-05-02     1965.0       269.0    31231.0  2020      5    2        5
# 124 2020-05-03     1900.0       474.0    27047.0  2020      5    3        6
# 125 2020-05-04     1389.0       174.0    22999.0  2020      5    4        0
# 126 2020-05-05     1221.0       195.0    32211.0  2020      5    5        1
# 127 2020-05-06     1075.0       236.0    37771.0  2020      5    6        2
# 128 2020-05-07     1444.0       369.0    13665.0  2020      5    7        3
# 129 2020-05-08     1401.0       274.0    45428.0  2020      5    8        4
# 130 2020-05-09     1327.0       243.0    36091.0  2020      5    9        5
# 131 2020-05-10     1083.0       194.0    31384.0  2020      5   10        6
# 132 2020-05-11      802.0       165.0    25823.0  2020      5   11        0
# 133 2020-05-12      744.0       179.0    39620.0  2020      5   12        1
# 134 2020-05-13     1402.0       172.0    37049.0  2020      5   13        2
# 135 2020-05-14      888.0       195.0    41131.0  2020      5   14        3
# 136 2020-05-15      992.0       262.0    39027.0  2020      5   15        4
# 137 2020-05-16      789.0       242.0    40657.0  2020      5   16        5
# 138 2020-05-17      875.0       153.0    33505.0  2020      5   17        6
# 139 2020-05-18      675.0       145.0    26101.0  2020      5   18        0
# 140 2020-05-19      451.0        99.0    40226.0  2020      5   19        1
# 141 2020-05-20      813.0       162.0    38617.0  2020      5   20        2
# 142 2020-05-21      665.0       161.0    40644.0  2020      5   21        3
# 143 2020-05-22      642.0       156.0    42987.0  2020      5   22        4
# 144 2020-05-23      652.0       130.0    42579.0  2020      5   23        5
# 145 2020-05-24      669.0       119.0    34206.0  2020      5   24        6
# 146 2020-05-25      531.0        50.0    20676.0  2020      5   25        0
# 147 2020-05-26      300.0        92.0    33944.0  2020      5   26        1
# 148 2020-05-27      397.0        78.0    37299.0  2020      5   27        2
# 149 2020-05-28      584.0       117.0    39838.0  2020      5   28        3
# 150 2020-05-29      593.0        70.0    38233.0  2020      5   29        4
# 151 2020-05-30      516.0        87.0    36051.0  2020      5   30        5
# 152 2020-05-31      416.0       111.0    28948.0  2020      5   31        6

# %%
covid_df_may_metrics=covid_df_may[['new_cases','new_deaths','new_tests']]

# %%
covid_df_may_metrics
# Out:
#      new_cases  new_deaths  new_tests
# 122     1872.0       285.0    43732.0
# 123     1965.0       269.0    31231.0
# 124     1900.0       474.0    27047.0
# 125     1389.0       174.0    22999.0
# 126     1221.0       195.0    32211.0
# 127     1075.0       236.0    37771.0
# 128     1444.0       369.0    13665.0
# 129     1401.0       274.0    45428.0
# 130     1327.0       243.0    36091.0
# 131     1083.0       194.0    31384.0
# 132      802.0       165.0    25823.0
# 133      744.0       179.0    39620.0
# 134     1402.0       172.0    37049.0
# 135      888.0       195.0    41131.0
# 136      992.0       262.0    39027.0
# 137      789.0       242.0    40657.0
# 138      875.0       153.0    33505.0
# 139      675.0       145.0    26101.0
# 140      451.0        99.0    40226.0
# 141      813.0       162.0    38617.0
# 142      665.0       161.0    40644.0
# 143      642.0       156.0    42987.0
# 144      652.0       130.0    42579.0
# 145      669.0       119.0    34206.0
# 146      531.0        50.0    20676.0
# 147      300.0        92.0    33944.0
# 148      397.0        78.0    37299.0
# 149      584.0       117.0    39838.0
# 150      593.0        70.0    38233.0
# 151      516.0        87.0    36051.0
# 152      416.0       111.0    28948.0

# %%
covid_df_may_metrics.sum()
# Out:
# new_cases       29073.0
# new_deaths       5658.0
# new_tests     1078720.0
# dtype: float64

# %% [markdown]
# We can use the groupby function to create a group for each month, select the columns we wish to aggregate, and aggregate them using the sum method.

# %%
covid_month_df = covid_df.groupby('month')[['new_cases', 'new_deaths', 'new_tests']].sum()
covid_month_df
# Out:
#        new_cases  new_deaths  new_tests
# month
# 1            3.0         0.0        0.0
# 2          885.0        21.0        0.0
# 3       100851.0     11570.0        0.0
# 4       101852.0     16091.0   419591.0
# 5        29073.0      5658.0  1078720.0
# 6         7772.0      1404.0   830354.0
# 7         6722.0       388.0   797692.0
# 8        21060.0       345.0  1098704.0
# 9         3297.0        20.0    54395.0
# 12           0.0         0.0        0.0

# %%
urlretrieve('https://gist.githubusercontent.com/aakashns/8684589ef4f266116cdce023377fc9c8/raw/99ce3826b2a9d1e6d0bde7e9e559fc8b6e9ac88b/locations.csv',
            'locations.csv')
# Out:
# ('locations.csv', <http.client.HTTPMessage at 0x7ba5d261b130>)

# %%
locations_df = pd.read_csv('locations.csv')

# %%
locations_df[locations_df.location=="Italy"]
# Out:
#    location continent  population  life_expectancy  \
# 97    Italy    Europe  60461828.0            83.51
#
#     hospital_beds_per_thousand  gdp_per_capita
# 97                        3.18       35220.084

# %%
covid_df['location']="Italy"

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday  \
# 0   2019-12-31        0.0         0.0        NaN  2019     12   31        1
# 1   2020-01-01        0.0         0.0        NaN  2020      1    1        2
# 2   2020-01-02        0.0         0.0        NaN  2020      1    2        3
# 3   2020-01-03        0.0         0.0        NaN  2020      1    3        4
# 4   2020-01-04        0.0         0.0        NaN  2020      1    4        5
# ..         ...        ...         ...        ...   ...    ...  ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020      8   30        6
# 244 2020-08-31     1365.0         4.0    42583.0  2020      8   31        0
# 245 2020-09-01      996.0         6.0    54395.0  2020      9    1        1
# 246 2020-09-02      975.0         8.0        NaN  2020      9    2        2
# 247 2020-09-03     1326.0         6.0        NaN  2020      9    3        3
#
#     location
# 0      Italy
# 1      Italy
# 2      Italy
# 3      Italy
# 4      Italy
# ..       ...
# 243    Italy
# 244    Italy
# 245    Italy
# 246    Italy
# 247    Italy
#
# [248 rows x 9 columns]

# %%
merged_df=covid_df.merge(locations_df,on="location")

# %%
merged_df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday  \
# 0   2019-12-31        0.0         0.0        NaN  2019     12   31        1
# 1   2020-01-01        0.0         0.0        NaN  2020      1    1        2
# 2   2020-01-02        0.0         0.0        NaN  2020      1    2        3
# 3   2020-01-03        0.0         0.0        NaN  2020      1    3        4
# 4   2020-01-04        0.0         0.0        NaN  2020      1    4        5
# ..         ...        ...         ...        ...   ...    ...  ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020      8   30        6
# 244 2020-08-31     1365.0         4.0    42583.0  2020      8   31        0
# 245 2020-09-01      996.0         6.0    54395.0  2020      9    1        1
# 246 2020-09-02      975.0         8.0        NaN  2020      9    2        2
# 247 2020-09-03     1326.0         6.0        NaN  2020      9    3        3
#
#     location continent  population  life_expectancy  \
# 0      Italy    Europe  60461828.0            83.51
# 1      Italy    Europe  60461828.0            83.51
# 2      Italy    Europe  60461828.0            83.51
# 3      Italy    Europe  60461828.0            83.51
# 4      Italy    Europe  60461828.0            83.51
# ..       ...       ...         ...              ...
# 243    Italy    Europe  60461828.0            83.51
# 244    Italy    Europe  60461828.0            83.51
# 245    Italy    Europe  60461828.0            83.51
# 246    Italy    Europe  60461828.0            83.51
# 247    Italy    Europe  60461828.0            83.51
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          3.18       35220.084
# 1                          3.18       35220.084
# 2                          3.18       35220.084
# 3                          3.18       35220.084
# 4                          3.18       35220.084
# ..                          ...             ...
# 243                        3.18       35220.084
# 244                        3.18       35220.084
# 245                        3.18       35220.084
# 246                        3.18       35220.084
# 247                        3.18       35220.084
#
# [248 rows x 14 columns]
